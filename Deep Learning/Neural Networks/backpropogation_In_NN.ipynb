# %% [markdown]
# **Coding back propagation from scratch**

# %% [markdown]
# ## Backpropagation Explanation
#
# The provided code demonstrates a simplified implementation of **backpropagation** for a single neuron with a ReLU activation function. The goal is to adjust the `weights` and `bias` of the neuron to minimize the `loss` between its `output` and a `target_output`.
#
# Here's a breakdown of the process:
#
# 1.  **Forward Pass:**
#     *   `linear_output = np.dot(weights, inputs) + bias`: This calculates the weighted sum of the inputs plus the bias. This is the 'pre-activation' value.
#     *   `output = relu(linear_output)`: The ReLU (Rectified Linear Unit) activation function is applied to the `linear_output`. `relu(x)` returns `x` if `x > 0`, and `0` otherwise.
#     *   `loss = (output - target_output) ** 2`: The mean squared error (MSE) is used as the loss function, measuring the squared difference between the `output` and the `target_output`.
#
# 2.  **Backward Pass (Derivative Calculation):**
#     The core of backpropagation involves calculating the gradient of the loss with respect to each parameter (weights and bias) using the chain rule. This tells us how much each parameter contributes to the error and in which direction it needs to be adjusted.
#
#     *   **`dloss_doutput = 2 * (output - target_output)`**:
#         This is the derivative of the loss function `L = (y_pred - y_true)^2` with respect to the `output` (`y_pred`). Using the power rule, `dL/dy_pred = 2 * (y_pred - y_true)`.
#
#     *   **`doutput_dlinear = relu_derivative(linear_output)`**:
#         This is the derivative of the ReLU activation function with respect to its input (`linear_output`).
#         *   If `linear_output > 0`, the derivative is `1`.
#         *   If `linear_output <= 0`, the derivative is `0`.
#
#     *   **`dlinear_dweights = inputs`**:
#         This is the derivative of the `linear_output` (`w*x + b`) with respect to the `weights` (`w`). The derivative of `w*x + b` with respect to `w` is `x` (the `inputs`).
#
#     *   **`dlinear_dbias = 1.0`**:
#         This is the derivative of the `linear_output` (`w*x + b`) with respect to the `bias` (`b`). The derivative of `w*x + b` with respect to `b` is `1`.
#
#     *   **Applying the Chain Rule:**
#         *   **`dloss_dlinear = dloss_doutput * doutput_dlinear`**:
#             This calculates the derivative of the loss with respect to the `linear_output`. It combines how sensitive the loss is to the neuron's output with how sensitive the neuron's output is to its pre-activation value.
#
#         *   **`dloss_dweights = dloss_dlinear * dlinear_dweights`**:
#             This calculates the final gradient of the loss with respect to the `weights`. It chains together `dloss_dlinear` (how much `linear_output` affects loss) and `dlinear_dweights` (how much `weights` affect `linear_output`).
#
#         *   **`dloss_dbias = dloss_dlinear * dlinear_dbias`**:
#             Similarly, this calculates the final gradient of the loss with respect to the `bias`. It combines `dloss_dlinear` with `dlinear_dbias`.
#
# 3.  **Parameter Update:**
#     *   `weights -= learning_rate * dloss_dweights`:
#     *   `bias -= learning_rate * dloss_dbias`:
#         The `weights` and `bias` are updated by subtracting a fraction (`learning_rate`) of their respective gradients. The `learning_rate` controls the size of the steps taken during optimization. Subtracting the gradient moves the parameters in the direction that reduces the loss.

# %%
import numpy as np

# Initail Parameters
weights = np.array([-3.0,-1.0,2.0])
bias = 1.0
inputs = np.array([1.0,-2.0,3.0])
target_output = 0.0
learning_rate = 0.001

def relu(x):
  return np.maximum(0,x)

def relu_derivative(x):
  # derivative eof x w.r.t x is 1
  return np.where(x>0,1.0,0.0)

for iteration in range(200):
  # Forward pass
  linear_output = np.dot(weights,inputs)+bias
  output = relu(linear_output)
  loss  = (output - target_output) ** 2

  # Backward Pass
  dloss_doutput = 2 * (output - target_output)
  doutput_dlinear = relu_derivative(linear_output)
  dlinear_dweights = inputs
  dlinear_dbias = 1.0

  dloss_dlinear = dloss_doutput * doutput_dlinear
  dloss_dweights = dloss_dlinear * dlinear_dweights
  dloss_dbias = dloss_dlinear * dlinear_dbias

  # Update weights and bias

  weights -= learning_rate * dloss_dweights
  bias -= learning_rate * dloss_dbias

  print(f"Iteration {iteration + 1}, Loss: {loss}")
print("Final weights: ",weights)
print(f"Final bias: ",bias)
# Out:
# Iteration 1, Loss: 36.0
# Iteration 2, Loss: 33.872399999999985
# Iteration 3, Loss: 31.870541159999995
# Iteration 4, Loss: 29.98699217744401
# Iteration 5, Loss: 28.21476093975706
# Iteration 6, Loss: 26.54726856821742
# Iteration 7, Loss: 24.978324995835766
# Iteration 8, Loss: 23.502105988581878
# Iteration 9, Loss: 22.113131524656684
# Iteration 10, Loss: 20.80624545154949
# Iteration 11, Loss: 19.576596345362915
# Iteration 12, Loss: 18.419619501351963
# Iteration 13, Loss: 17.331019988822064
# Iteration 14, Loss: 16.306756707482677
# Iteration 15, Loss: 15.343027386070442
# Iteration 16, Loss: 14.43625446755368
# Iteration 17, Loss: 13.583071828521268
# Iteration 18, Loss: 12.780312283455652
# Iteration 19, Loss: 12.024995827503426
# Iteration 20, Loss: 11.314318574097976
# Iteration 21, Loss: 10.645642346368787
# Iteration 22, Loss: 10.016484883698395
# Iteration 23, Loss: 9.424510627071816
# Iteration 24, Loss: 8.867522049011871
# Iteration 25, Loss: 8.34345149591527
# ...
